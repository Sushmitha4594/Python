# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmitha4594/Python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Baby steps control structures

# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=10
Num2=30
add=Num1+Num2
print(add)
# Out:
# 40

# %%
bmi=int(input("Enter the BMI Index: "))
if bmi < 18.5:
 print("Under weight")
elif 18.5 <= bmi < 25:
 print("Normal weight")
elif 25<= bmi < 30:
 print("Over weight")
else:
 print("Very over weight")
# Out:
# Enter the BMI Index: 34
# Very over weight

# %% [markdown]
# Extra Assignment level 1 python
